# %%
#KEY = "M3QHDC2-J194Z2X-M8ND0YK-EK2ZPHP" # TEST
KEY = "87Y9HHA-GEZ4TB9-HA1S789-JXBWMTS" # PROD

# %%
from nowpayments import NOWPayments
payment = NOWPayments(KEY)
payment._IS_SANDBOX = True
status = payment.get_api_status()
print (status)
# Out:
# {'message': 'OK'}

# %%
payment.get_payment_status(6162689867)
# Out:
# {'payment_id': 6162689867,
#  'invoice_id': None,
#  'payment_status': 'waiting',
#  'pay_address': 'TEkYLhWoCLkv7rKJURp7HhpbgnV6GRzkbe',
#  'price_amount': 10,
#  'price_currency': 'usd',
#  'pay_amount': 9.99,
#  'actually_paid': 0,
#  'pay_currency': 'usdttrc20',
#  'order_id': None,
#  'order_description': None,
#  'purchase_id': 4869734709,
#  'outcome_amount': 7.911745,
#  'outcome_currency': 'usdttrc20',
#  'payout_hash': None,
#  'payin_hash': None,
#  'created_at': '2023-02-08T02:10:35.767Z',
#  'updated_at': '2023-02-08T02:10:43.787Z',
#  'burning_percent': None,
#  'type': 'crypto2crypto'}

# %%
payment.create_payment(price_amount=10, price_currency='USD', pay_currency='USDTTRC20')
# Out:
# {'payment_id': '6162689867',
#  'payment_status': 'waiting',
#  'pay_address': 'TEkYLhWoCLkv7rKJURp7HhpbgnV6GRzkbe',
#  'price_amount': 10,
#  'price_currency': 'usd',
#  'pay_amount': 9.99,
#  'amount_received': 7.911745,
#  'pay_currency': 'usdttrc20',
#  'order_id': None,
#  'order_description': None,
#  'ipn_callback_url': None,
#  'created_at': '2023-02-08T02:10:35.767Z',
#  'updated_at': '2023-02-08T02:10:35.767Z',
#  'purchase_id': '4869734709',
#  'smart_contract': None,
#  'network': 'trx',
#  'network_precision': None,
#  'time_limit': None,
#  'burning_percent': None,
#  'expiration_estimate_date': '2023-02-08T02:30:35.767Z',
#  'is_fixed_rate': False,
#  'is_fee_paid_by_user': False,
#  'valid_until': '2023-02-09T02:10:35.767Z',
#  'type': 'crypto2crypto'}

# %%
payment.get_available_currencies()
# Out:
# {'currencies': ['btg',
#   'xmr',
#   'btc',
#   'zec',
#   'etc',
#   'xvg',
#   'ada',
#   'ltc',
#   'bch',
#   'qtum',
#   'dash',
#   'xlm',
#   'xrp',
#   'xem',
#   'omg',
#   'dgb',
#   'cvc',
#   'dcr',
#   'doge',
#   'trx',
#   'kmd',
#   'rep',
#   'bat',
#   'eos',
#   'mana',
#   'ark',
#   'waves',
#   'nano',
#   'tusd',
#   'vet',
#   'zen',
#   'fun',
#   'neo',
#   'gas',
#   'bsv',
#   'usdc',
#   'ont',
#   'xtz',
#   'hot',
#   'icx',
#   'iotx',
#   'knc',
#   'link',
#   'rvn',
#   'enj',
#   'bnbmainnet',
#   'vib',
#   'bcd',
#   'usdt',
#   'atom',
#   'usdterc20',
#   'cro',
#   'dai',
#   'hbar',
#   'ht',
#   'wabi',
#   'matic',
#   'busd',
#   'algo',
#   'usdttrc20',
#   'gt',
#   'stpt',
#   'ftt',
#   'gusd',
#   'dot',
#   'coti',
#   'theta',
#   'ava',
#   'yfi',
#   'luna',
#   'uni',
#   'tfuel',
#   'fil',
#   'aave',
#   'one',
#   'now',
#   'okb',
#   'klay',
#   'ocean',
#   'egld',
#   'axs',
#   'strax',
#   'srk',
#   'ftm',
# ...
